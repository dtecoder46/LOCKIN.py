# %%
import time

# %%
# Purpose: to check how fast a certain block of code runs
# Parameters: function
# Return: inner

def stopwatch(function):
    def inner():
        start = time.time() # 0 seconds
        function()
        end = time.time() # time it takes for the function to run

        print(f"{end-start} seconds") 

    return inner

# %% [markdown]
# # Read in the YAML file content

# %%
# Purpose: to transform a YAML file of tasks into separate dictionaries
# Parameters, Return: none

@stopwatch
def extract_yml():

    # get file content

    yml_file = open("task.yaml", "r")
    yml_content = yml_file.read()

    # split key-value pairs into a list as separate 
    print(yml_content.split("\n"))

extract_yml()
# Out:
# ['Interact with posts: not done', 'Apply to Under Armour: not done', 'Apply to Mariner Finance: not done', 'Apply to BioMarin: not done', 'Apply to CareYaya: not done', 'Apply to ACE: not done', 'Apply to U of W: not done', '#', 'Westbound: not done', 'World Roleplay: not done', 'Minecraft: not done', '#', 'Lifting weights: not done', 'Squatting: not done', '']
# 0.0010707378387451172 seconds
